# %% [markdown]
# # MIT Python Course
#
# ## Problem Set 1 (Part A)
#
# 1. Call the cost of your dream home  **total_cost** .<br>
# 2. Call the portion of the cost needed for a down payment **portion_down_payment** . For simplicity, assume that portion_down_payment = 0.25 (25%).\
# 3. Call the amount that you have saved thus far **current_savings** . You start with a current savings of $0.\
# 4. Assume that you invest your current savings wisely, with an annual return of r (in other words, at the end of each month, you receive an additional **current_savings** *r/12 funds to put into your savings – the 12 is because r is an annual rate). Assume that your investments earn a return of r = 0.04 (4%).\
# 5. Assume your annual salary is **annual_salary** .\
# 6. Assume you are going to dedicate a certain amount of your salary each month to saving for the down payment. Call that **portion_saved** . This variable should be in decimal form (i.e. 0.1 for 10%).\
# 7. At the end of each month, your savings will be increased by the return on your investment, plus a percentage of your monthly salary (annual salary / 12).\
# \
# Write a program to calculate how many months it will take you to save up enough money for a down payment. You will want your main variables to be floats, so you should cast user inputs to floats.\
# \
# Your program should ask the user to enter the following variables:
# 1. The starting annual salary (**annual_salary**)
# 2. The portion of salary to be saved (**portion_saved**)
# 3. The cost of your dream home (**total_cost**)

# %%
total_cost = float(input('Enter the cost of your dream house: '))
annual_salary = float(input('Enter your starting annual salary: '))
portion_saved = float(input('Enter the portion of your salary to be saved (in decimal, i.e., 0.1 for 10%): '))

portion_down_payment = 0.25*total_cost
print('Required down payment:', portion_down_payment)
current_saving = 0
r = 0.04 # rate of annual return

month = 0
while current_saving < portion_down_payment:
    # print('month:', month,',','current saving',current_saving)
    current_saving += portion_saved*(annual_salary/12) + r*current_saving/12
    month += 1
    
# print('month:', month,',','current saving',current_saving)  
print('Saving after', month,'month(s) is $'+str(current_saving))
print('You can afford the downpayment of your dream house in', month, 'month(s).')
# Out:
# Enter the cost of your dream house: 1000000
# Enter your starting annual salary: 330000
# Enter the portion of your salary to be saved (in decimal, i.e., 0.1 for 10%): 0.4
# Required down payment: 250000.0
# Saving after 22 month(s) is $250661.2385099735
# You can afford the downpayment of your dream house in 22 month(s).

# %% [markdown]
# ## Problem Set 1 (Part B)
#
# Modify your program to include the following\
# 1. Have the user input a semi-annual salary **raise semi_annual_raise** (as a decimal percentage)
# 2. After the 6th month, increase your salary by that percentage. Do the same after the 12th
# month, the 18th month, and so on.\
# \
# Write a program to calculate how many months it will take you save up enough money for a down
# payment. Like before, assume that your investments earn a return of r = 0.04 (or 4%) and the
# required down payment percentage is 0.25 (or 25%). Have the user enter the following variables:
# \
# 1. The starting annual salary (**annual_salary**)\
# 2. The percentage of salary to be saved (**portion_saved**)\
# 3. The cost of your dream home (**total_cost**)\
# 4. The semiannual salary raise (**semi_annual_raise**)

# %%
total_cost = float(input('Enter the cost of your dream house: '))
annual_salary = float(input('Enter your starting annual salary: '))
portion_saved = float(input('Enter the portion of your salary to be saved (in decimal, i.e., 0.1 for 10%): '))
semi_annual_raise = float(input('Enter a semi-annual salary raise (in decimal): '))
print('\n')

portion_down_payment = 0.25*total_cost
print('Required down payment:', round(portion_down_payment,2))
current_saving = 0
r = 0.04 # rate of annual return

month = 0
raise_counter = 0
while current_saving < portion_down_payment:
    # print('month:', month,',','current saving',current_saving)
    
    if raise_counter != (month//6):
        annual_salary += annual_salary*semi_annual_raise 
        raise_counter += 1

    current_saving += portion_saved*(annual_salary/12) + r*current_saving/12
    month += 1
    print('month:', month,',','current saving',current_saving)  
print('Saving after', month,'month(s) is $'+str(round(current_saving,2)))
print('You can afford the downpayment of your dream house in', month, 'month(s).')
# Out:
# Enter the cost of your dream house: 1e6
# Enter your starting annual salary: 150e3
# Enter the portion of your salary to be saved (in decimal, i.e., 0.1 for 10%): 0.4412
# Enter a semi-annual salary raise (in decimal): 0.07
#
#
# Required down payment: 250000.0
# month: 1 , current saving 5515.0
# month: 2 , current saving 11048.383333333333
# month: 3 , current saving 16600.211277777777
# month: 4 , current saving 22170.54531537037
# month: 5 , current saving 27759.447133088273
# month: 6 , current saving 33366.978623531904
# month: 7 , current saving 39379.25188561034
# month: 8 , current saving 45411.56605856238
# month: 9 , current saving 51463.987945424255
# month: 10 , current saving 57536.584571909
# month: 11 , current saving 63629.4231871487
# month: 12 , current saving 69742.57126443919
# month: 13 , current saving 76289.17000198732
# month: 14 , current saving 82857.59073532728
# month: 15 , current saving 89447.90620444504
# month: 16 , current saving 96060.18939179319
# ...

# %% [markdown]
# ## Problem Set 1 (Part C)
#
# To simplify things, assume:\
# 1. Your semiannual raise is .07 (7%)\
# 2. Your investments have an annual return of 0.04 (4%)\
# 3. The down payment is 0.25 (25%) of the cost of the house\
# 4. The cost of the house that you are saving for is \\$1M\
# \
# You are now going to try to find the best rate of savings to achieve a down payment on a \\$1M house in 36 months. Since hitting this exactly is a challenge, we simply want your savings to be within \\$100 of the required down payment.\
# \
# Write a program to calculate the best savings rate, as a function of your starting salary. You should use bisection search to help you do this efficiently. You should keep track of the number of steps it takes your bisections search to finish. You should be able to reuse some of the code you wrote for part B in this problem.<br>
# <br>
# Because we are searching for a value that is in principle a float, we are going to limit ourselves to two decimals of accuracy (i.e., we may want to save at 7.04% or 0.0704 in decimal – but we are not going to worry about the difference between 7.041% and 7.039%). This means we can search for an integer between 0 and 10000 (using integer division), and then convert it to a decimal percentage (using float division) to use when we are calculating the current_savings after 36 months. By using this range, there are only a finite number of numbers that we are searching over, as opposed to the infinite number of decimals between 0 and 1. This range will help prevent infinite loops. The reason we use 0 to 10000 is to account for two additional decimal places in the range 0% to 100%. Your code should print out a decimal (e.g. 0.0704 for 7.04%).<br>
# <br>
# Try different inputs for your starting salary, and see how the percentage you need to save changes to reach your desired down payment. Also keep in mind it may not be possible for to save a down payment in a year and a half for some salaries. In this case your function should notify the user that it is not possible to save for the down payment in 36 months with a print statement.<br>
# <br>
# Test Case 1 >>> Enter the starting salary: 150000 Best savings rate: 0.4411 Steps in bisection search: 12 >>> <br>
# Test Case 2 >>> Enter the starting salary: 300000 Best savings rate: 0.2206 Steps in bisection search: 9 >>> <br>
# Test Case 3 >>> Enter the starting salary: 10000 It is not possible to pay the down payment in three years. >>>

# %%
original_annual_salary = float(input('Enter your starting annual salary: '))
print('\n')

total_cost = 1000000
portion_down_payment = 0.25*total_cost
semi_annual_raise = 0.07
current_saving = 0
r = 0.04 # rate of annual return

upper_limit = 10000
lower_limit = 0
iteration = 0

while abs(current_saving - portion_down_payment) > 100 or current_saving < portion_down_payment:

    if iteration > 1:
        if current_saving > portion_down_payment:
            upper_limit = saving_rate
        else:
            lower_limit = saving_rate
    saving_rate = (lower_limit + upper_limit) / 2
    if saving_rate == 10000:
        print('It is not possible to collect the down payment in 36 months.')
        break

    annual_salary = original_annual_salary
    current_saving = 0
    raise_counter = 0
    iteration += 1

    for month in range(36):
        if raise_counter != (month//6):
            annual_salary += annual_salary*semi_annual_raise
            raise_counter += 1
        current_saving += (saving_rate/10000)*(annual_salary/12) + r*current_saving/12
    print("iteration: ", iteration, " ,saving rate: ", round(saving_rate/10000,4)," ,current saving: $"+str(round(current_saving,2)))

print('\n')
print("Required down payment: $"+ str(portion_down_payment))
print("Saving after 36 months: $"+ str(round(current_saving,2)), "with", round(saving_rate/10000,4), "saving rate")
# Out:
# Enter your starting annual salary: 1e4
#
#
# iteration:  1  ,saving rate:  0.5  ,current saving: $18892.48
# iteration:  2  ,saving rate:  0.5  ,current saving: $18892.48
# iteration:  3  ,saving rate:  0.75  ,current saving: $28338.72
# iteration:  4  ,saving rate:  0.875  ,current saving: $33061.84
# iteration:  5  ,saving rate:  0.9375  ,current saving: $35423.4
# iteration:  6  ,saving rate:  0.9688  ,current saving: $36604.18
# iteration:  7  ,saving rate:  0.9844  ,current saving: $37194.57
# iteration:  8  ,saving rate:  0.9922  ,current saving: $37489.77
# iteration:  9  ,saving rate:  0.9961  ,current saving: $37637.36
# iteration:  10  ,saving rate:  0.998  ,current saving: $37711.16
# iteration:  11  ,saving rate:  0.999  ,current saving: $37748.06
# iteration:  12  ,saving rate:  0.9995  ,current saving: $37766.51
# iteration:  13  ,saving rate:  0.9998  ,current saving: $37775.74
# iteration:  14  ,saving rate:  0.9999  ,current saving: $37780.35
# ...
